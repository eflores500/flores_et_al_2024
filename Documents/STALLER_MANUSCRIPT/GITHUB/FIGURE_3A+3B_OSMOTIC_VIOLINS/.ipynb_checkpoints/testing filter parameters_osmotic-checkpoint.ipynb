# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl
import seaborn as sns
import glob
import warnings
import math

###IMPORT DATAFRAME###
df = pd.read_csv('OSMOTIC_PERTURBATIONS_MASTER_HIF1A_CITED2_CONCATENATED.csv')
#df = df.drop('Unnamed: 0', axis=1)

# Drop any rows where 'protein' is 'HIF1A'
#df = df1[df1['protein'] != 'HIF1A']

# %%
columns_list = df.columns.tolist()

print(columns_list)
# Out:
# ['Unnamed: 0', 'IDR', 'date', 'condition', 'well', 'area_before', 'D_before', 'A_before', 'D_before std', 'A_before std', 'D/A before', 'directA_before', 'area_after', 'D_after', 'A_after', 'D_after std', 'A_after std', 'D/A after', 'directA_after', 'log directA_before', 'log directA_after', 'A_corr_before', 'D/A_corr_before', 'A_corr_after', 'D/A_corr_after', 'Ef_before', 'Ef_after', 'delta Ef', 'd_directA', 'protein', 'mut name']

# %%
# Assuming you have a DataFrame named "df" with columns 'IDR', 'log directA_before', and 'Ef_before'

# Get unique IDRs from the DataFrame
unique_idrs = df['IDR'].unique()

# Calculate the number of rows and columns for the subplot grid
num_rows = math.ceil(len(unique_idrs) / 2)
num_cols = 2

# Create a grid of subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, 6 * num_rows))

for i, idr in enumerate(unique_idrs):
    # Calculate the row and column indices for the current subplot
    row = i // num_cols
    col = i % num_cols
    
    # Filter the DataFrame for the current IDR
    subset = df[df['IDR'] == idr]
    
    # Create a scatter plot with 'log directA_before' on the x-axis and 'Ef_before' on the y-axis
    axes[row, col].scatter(subset['log directA_before'], subset['Ef_before'])
    
    # Set title for the subplot
    axes[row, col].set_title(f'IDR {idr}')
    
    # Add labels
    axes[row, col].set_xlabel('log directA')
    axes[row, col].set_ylabel('Ef')
# Set x-axis limits to 10000
    #axes[row, col].set_xlim(0, 2000)
# Remove any empty subplots if there are an odd number of IDRs
if len(unique_idrs) % 2 != 0:
    fig.delaxes(axes[-1, -1])

# Adjust spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Assuming you have a DataFrame named "df" with columns 'IDR', 'log directA_before', and 'Ef_before'

# Get unique IDRs from the DataFrame
unique_idrs = df['IDR'].unique()

# Calculate the number of rows and columns for the subplot grid
num_rows = math.ceil(len(unique_idrs) / 2)
num_cols = 2

# Create a grid of subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, 6 * num_rows))

for i, idr in enumerate(unique_idrs):
    # Calculate the row and column indices for the current subplot
    row = i // num_cols
    col = i % num_cols
    
    # Filter the DataFrame for the current IDR
    subset = df[df['IDR'] == idr]
    
    # Create a scatter plot with 'log directA_before' on the x-axis and 'Ef_before' on the y-axis
    axes[row, col].scatter(subset['A'], subset['Ef'])
    
    # Set title for the subplot
    axes[row, col].set_title(f'IDR {idr}')
    
    # Add labels
    axes[row, col].set_xlabel('A')
    axes[row, col].set_ylabel('Ef')
# Set x-axis limits to 10000
    #axes[row, col].set_xlim(0, 2000)
# Remove any empty subplots if there are an odd number of IDRs
if len(unique_idrs) % 2 != 0:
    fig.delaxes(axes[-1, -1])

# Adjust spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'A'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 22
#      19 subset = df[df['IDR'] == idr]
#      21 # Create a scatter plot with 'log directA_before' on the x-axis and 'Ef_before' on the y-axis
# ---> 22 axes[row, col].scatter(subset['A'], subset['Ef'])
#      24 # Set title for the subplot
#      25 axes[row, col].set_title(f'IDR {idr}')
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'A'

# %%
import matplotlib.pyplot as plt
import math

# Assuming you have a DataFrame named "df" with columns 'IDR', 'd_directA', 'Ef_after', and 'repeat'

# Get unique IDRs from the DataFrame
unique_idrs = df['IDR'].unique()

# Calculate the number of rows and columns for the subplot grid
num_rows = math.ceil(len(unique_idrs) / 2)
num_cols = 2

# Create a grid of subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, 6 * num_rows), sharex=True, sharey=True)

for i, idr in enumerate(unique_idrs):
    # Calculate the row and column indices for the current subplot
    row = i // num_cols
    col = i % num_cols
    
    # Filter the DataFrame for the current IDR
    subset = df[df['IDR'] == idr]
    
    # Create a histogram with 'd_directA' on the x-axis
    axes[row, col].hist(subset['delta Ef'], bins=20, color='skyblue', edgecolor='black', alpha=0.7)
    
    # Set title for the subplot
    axes[row, col].set_title(f'IDR {idr}')
    
    # Add labels
    axes[row, col].set_xlabel('D std')
    axes[row, col].set_ylabel('Count')
    
    # Set x-axis limits to 10000 (if desired)
    # axes[row, col].set_xlim(0, 10000)

# Remove any empty subplots if there are an odd number of IDRs
if len(unique_idrs) % 2 != 0:
    fig.delaxes(axes[-1, -1])

# Adjust spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
##assigning filters 
##REMEMBER CUTOFF IS AT 15000, USING DIRECTA
#df_filtered = df[(df['D_before'] < 50000) & (df['A_before'] < 50000)]

# df_filtered = df[(df['D_before std']<4000)]
# df_filtered = df_filtered[(df_filtered['D_after std']<4000)]
# df_filtered = df_filtered[(df_filtered['A_before std']<4000)]
# df_filtered = df_filtered[(df_filtered['A_after std']<4000)]

# df_filtered = df_filtered[(df_filtered['area_before']<10000)]
# df_filtered = df_filtered[(df_filtered['area_after']<10000)]

# df_filtered = df_filtered[(df_filtered['log directA_before']>3.1)]
# df_filtered = df_filtered[(df_filtered['log directA_after']>3.1)]


# df_filtered = df_filtered[(df_filtered['A_after'] > 500) & (df_filtered['A_after'] < 50000)]
# df_filtered = df_filtered[(df_filtered['Ef_before']>0)]
# df_filtered = df_filtered[(df_filtered['Ef_after']>0)]
# df_filtered = df_filtered[(df_filtered['area_before']<40000)]
# df_filtered = df_filtered[(df_filtered['d_directA']<30000)]

df_filtered = df[(df['d_directA']<1000)]


df_filtered = df_filtered[(df_filtered['area_before']<10000)]
#df_filtered = df_filtered[(df_filtered['area_after']<10000)]

df_filtered = df_filtered[(df_filtered['log directA_before']>3.1)]
df_filtered = df_filtered[(df_filtered['log directA_before']<3.7)]

df_filtered
# Out:
#        Unnamed: 0  IDR    date  condition          well  area_before  \
# 138          3368   10  230304        100  B4_10_230304      333.036
# 141          3371   10  230304        100  B4_10_230304     1031.006
# 143          3373   10  230304        100  B4_10_230304      256.880
# 144          3374   10  230304        100  B4_10_230304     1305.314
# 157          3387   10  230304        100  B4_10_230304      248.641
# ...           ...  ...     ...        ...           ...          ...
# 90188        2160    4  230811        750   E4_4_230811     1091.318
# 90197        2169    4  230811        750   E4_4_230811      794.722
# 90198        2170    4  230811        750   E4_4_230811      940.062
# 90201        2173    4  230811        750   E4_4_230811      703.674
# 90203        2175    4  230811        750   E4_4_230811      729.235
#
#        D_before  A_before  D_before std  A_before std  ...  A_corr_before  \
# 138    1124.832  2685.236       154.522       360.277  ...     1682.94776
# 141    2625.725  7259.526      2154.302      7692.203  ...     4915.68281
# 143    1939.778  3520.073       811.763      1468.003  ...     1923.88382
# 144    2585.516  6314.728      1207.106      3068.140  ...     4133.00534
# 157    1341.483  2781.720       368.639       658.146  ...     1725.17474
# ...         ...       ...           ...           ...  ...            ...
# 90188  1291.840  2071.317       412.218       859.561  ...     1141.60716
# 90197  1914.685  2958.610       929.970      1313.943  ...     1604.11588
# 90198  1658.011  2596.129       571.964       828.408  ...     1398.41782
# 90201  1536.464  2419.266       559.179       790.470  ...     1322.28886
# 90203  1479.696  2351.653       363.255       498.526  ...     1259.13931
#
#        D/A_corr_before  A_corr_after  D/A_corr_after  Ef_before  Ef_after  \
# 138           0.668370    1673.30883        0.537484   0.599387  0.650413
# 141           0.534153    5054.70953        0.496064   0.651826  0.668421
# 143           1.008262    1854.98767        0.866705   0.497943  0.535703
# 144           0.625578    4207.30499        0.546074   0.615166  0.646800
# 157           0.777593    1312.30408        0.648603   0.562559  0.606574
# ...                ...           ...             ...        ...       ...
# 90188         1.131598     855.69351        1.267218   0.469132  0.441069
# 90197         1.193608    1288.55090        1.383683   0.455870  0.419519
# 90198         1.185633    1118.31610        1.335018   0.457533  0.428262
# 90201         1.161973    1018.34018        1.363940   0.462540  0.423023
# 90203         1.175165     977.82486        1.362641   0.459735  0.423255
#
#        delta Ef  d_directA  protein  mut name
# 138    0.051026    182.981   CITED2        WT
# 141    0.016595      3.833   CITED2        WT
# 143    0.037760    283.978   CITED2        WT
# 144    0.031634    192.443   CITED2        WT
# 157    0.044016    542.233   CITED2        WT
# ...         ...        ...      ...       ...
# 90188 -0.028062    276.235    HIF1A      RK>E
# 90197 -0.036351    252.865    HIF1A      RK>E
# 90198 -0.029271    259.119    HIF1A      RK>E
# 90201 -0.039518    254.445    HIF1A      RK>E
# 90203 -0.036480    251.981    HIF1A      RK>E
#
# [35030 rows x 31 columns]

# %%
# Assuming you have a DataFrame named "df" with columns 'IDR', 'd_directA', 'Ef_after', and 'repeat'


# Get unique IDRs from the filtered DataFrame
unique_idrs = df_filtered['IDR'].unique()

# Calculate the number of rows and columns for the subplot grid
num_rows = 4
num_cols = 3

# Create a grid of subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, 6 * num_rows), sharex=True, sharey=True)

for i, idr in enumerate(unique_idrs):
    # Calculate the row and column indices for the current subplot
    row = i // num_cols
    col = i % num_cols
    
    # Filter the filtered DataFrame for the current IDR
    subset = df_filtered[df_filtered['IDR'] == idr]
    
    # Create a scatter plot with 'd_directA' on the x-axis, 'Ef_after' on the y-axis, and color-coded by 'repeat'
    scatter = axes[row, col].scatter(subset['log directA_before'], subset['Ef_before'], cmap='tab10')
    
    # Set title for the subplot
    axes[row, col].set_title(f'IDR {idr}')
    
    # Add labels
    axes[row, col].set_xlabel('log directA')
    axes[row, col].set_ylabel('Ef')
    
    # Set x-axis limits to 10000
    #axes[row, col].set_xlim(0, 10000)

# Remove any empty subplots if there are an odd number of IDRs
if len(unique_idrs) % 2 != 0:
    fig.delaxes(axes[-1, -1])

# Adjust spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# /var/folders/sk/wwp89bvx0x59gfggckwfs52r0000gn/T/ipykernel_55892/1548768090.py:23: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = axes[row, col].scatter(subset['log directA_before'], subset['Ef_before'], cmap='tab10')
